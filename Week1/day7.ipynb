# %%
#Step 1 
import random
logo = ''' 
 _                                             
| |                                            
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __  
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \ 
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |                      
                   |___/    '''
print(logo)


word_list = word_list = [
'abruptly', 
'absurd', 
'abyss', 
'affix', 
'askew', 
'avenue', 
'awkward', 
'axiom', 
'azure', 
'bagpipes', 
'bandwagon', 
'banjo', 
'bayou', 
'beekeeper', 
'bikini', 
'blitz', 
'blizzard', 
'boggle', 
'bookworm', 
'boxcar', 
'boxful', 
'buckaroo', 
'buffalo', 
'buffoon', 
'buxom', 
'buzzard', 
'buzzing', 
'buzzwords', 
'caliph', 
'cobweb', 
'cockiness', 
'croquet', 
'crypt', 
'curacao', 
'cycle', 
'daiquiri', 
'dirndl', 
'disavow', 
'dizzying', 
'duplex', 
'dwarves', 
'embezzle', 
'equip', 
'espionage', 
'euouae', 
'exodus', 
'faking', 
'fishhook', 
'fixable', 
'fjord', 
'flapjack', 
'flopping', 
'fluffiness', 
'flyby', 
'foxglove', 
'frazzled', 
'frizzled', 
'fuchsia', 
'funny', 
'gabby', 
'galaxy', 
'galvanize', 
'gazebo', 
'giaour', 
'gizmo', 
'glowworm', 
'glyph', 
'gnarly', 
'gnostic', 
'gossip', 
'grogginess', 
'haiku', 
'haphazard', 
'hyphen', 
'iatrogenic', 
'icebox', 
'injury', 
'ivory', 
'ivy', 
'jackpot', 
'jaundice', 
'jawbreaker', 
'jaywalk', 
'jazziest', 
'jazzy', 
'jelly', 
'jigsaw', 
'jinx', 
'jiujitsu', 
'jockey', 
'jogging', 
'joking', 
'jovial', 
'joyful', 
'juicy', 
'jukebox', 
'jumbo', 
'kayak', 
'kazoo', 
'keyhole', 
'khaki', 
'kilobyte', 
'kiosk', 
'kitsch', 
'kiwifruit', 
'klutz', 
'knapsack', 
'larynx', 
'lengths', 
'lucky', 
'luxury', 
'lymph', 
'marquis', 
'matrix', 
'megahertz', 
'microwave', 
'mnemonic', 
'mystify', 
'naphtha', 
'nightclub', 
'nowadays', 
'numbskull', 
'nymph', 
'onyx', 
'ovary', 
'oxidize', 
'oxygen', 
'pajama', 
'peekaboo', 
'phlegm', 
'pixel', 
'pizazz', 
'pneumonia', 
'polka', 
'pshaw', 
'psyche', 
'puppy', 
'puzzling', 
'quartz', 
'queue', 
'quips', 
'quixotic', 
'quiz', 
'quizzes', 
'quorum', 
'razzmatazz', 
'rhubarb', 
'rhythm', 
'rickshaw', 
'schnapps', 
'scratch', 
'shiv', 
'snazzy', 
'sphinx', 
'spritz', 
'squawk', 
'staff', 
'strength', 
'strengths', 
'stretch', 
'stronghold', 
'stymied', 
'subway', 
'swivel', 
'syndrome', 
'thriftless', 
'thumbscrew', 
'topaz', 
'transcript', 
'transgress', 
'transplant', 
'triphthong', 
'twelfth', 
'twelfths', 
'unknown', 
'unworthy', 
'unzip', 
'uptown', 
'vaporize', 
'vixen', 
'vodka', 
'voodoo', 
'vortex', 
'voyeurism', 
'walkway', 
'waltz', 
'wave', 
'wavy', 
'waxy', 
'wellspring', 
'wheezy', 
'whiskey', 
'whizzing', 
'whomever', 
'wimpy', 
'witchcraft', 
'wizard', 
'woozy', 
'wristwatch', 
'wyvern', 
'xylophone', 
'yachtsman', 
'yippee', 
'yoked', 
'youthful', 
'yummy', 
'zephyr', 
'zigzag', 
'zigzagging', 
'zilch', 
'zipper', 
'zodiac', 
'zombie', 
]
chosen_word = random.choice(word_list)



blank_list =[]


for dash in range(len(chosen_word)):
    blank_list.append('_')
    finder_list = []
stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']
no_lives = 6
while '_' in blank_list:
    guess = str(input('pls guess a letter: '))
    guess = guess.lower()
    
    
    if guess not in chosen_word:
        no_lives-=1
        print(f'{guess} is not present in the word, you jus lost a life, {stages[no_lives]}{no_lives} lives remaining')
    if no_lives == 0:
        print()
        print('you lose: \nGame over\n==========')
        print(f'the correct word is {chosen_word}')
        break
    if guess in blank_list:
        print()
        print(f'you have already guessed {guess}')
        
        
    
    for i in chosen_word:
        if i == guess:
            finder_list.append('right')
        else:
            finder_list.append('wrong')

    for idx in range(len(finder_list)):
        if finder_list[idx] == 'right':
            blank_list[idx] = guess
            
    print(f"{' '.join(blank_list)}")
    finder_list.clear()
if no_lives > 0:
    print()
    print('you win!!!!!!!!!!!!')
    print(f'the correct word is {chosen_word}')
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# f is not present in the word, you jus lost a life,
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
# 5 lives remaining
# _ _ _ _ _ _ _ _ _ _
# f is not present in the word, you jus lost a life,
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
# 4 lives remaining
# _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ r _ _
# _ _ _ _ _ s _ r _ _
# d is not present in the word, you jus lost a life,
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========3 lives remaining
# _ _ _ _ _ s _ r _ _
# _ _ _ _ _ s _ r _ w
# _ _ _ m _ s _ r _ w
# i is not present in the word, you jus lost a life,
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
# 2 lives remaining
# _ _ _ m _ s _ r _ w
# ...

# %%
angles_dict = {
    'triangle': 3,
    'square': 4,
    'pentagon': 5,
    'hexagon': 6,
    'heptagon': 7,
    'octagon': 8,
    'nonagon': 9,
    'decagon': 10
} 
print(angles_dict['triangle'])
# Out:
# 3

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-52931990a09f> in <module>
#      28         return no_sides
#      29
# ---> 30 no_sides = angles(angles_dict)
#      31 angle = 360/no_sides
#      32
#
# <ipython-input-5-52931990a09f> in angles(angles_dict)
#      25 def angles(angles_dict):
#      26     for idx in range(len(polygons)):
# ---> 27         no_sides = angles_dict[idx+polygon]
#      28         return no_sides
#      29
#
# KeyError: 0
